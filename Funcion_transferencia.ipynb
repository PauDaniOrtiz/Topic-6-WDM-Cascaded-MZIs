# %%
import numpy as np
from sympy import symbols, Matrix, exp, I, simplify
import matplotlib.pyplot as plt

# %% [markdown]
# # Código FINAL

# %%
#---- parámetros----
alpha=0

n_eff0=1.6
n_g=4.2
#n_g=0
wvl0=1.55e-6
wvlf=1.6e-6
wvli=1.5e-6
FSR=(wvlf-wvli)/4
L=wvl0**2/(n_g*FSR)
wvl=np.linspace(1500e-9,1599e-9,2000)

phi=np.pi/2

print(L)
# Out:
# 2.2880952380952403e-05

# %%
n_eff = n_eff0+(n_eff0-n_g)*(wvl-wvl0)/wvl0
#n_eff=n_eff0
beta=2*np.pi*n_eff/wvl

# Señal de entrada In

In=1

D=np.exp(-1j*beta*L)
D1=np.exp(-1j*beta*L/2)
D2=np.exp(-1j*beta*L/4)

PS1=np.exp(1j*0)
PS1_1=np.exp(1j*(np.pi/2))

PS2=np.exp(1j*np.pi*(1/4+1/2))
#PS2=np.exp(1j*np.pi)
PS3=np.exp(1j*np.pi*(3/4-1))

PS4=np.exp(1j*np.pi*(-1/2))
PS5=np.exp(1j*np.pi*(1/2))



Out1=1/8 * In * (D+1)*(D1*PS1+1)*(D2*PS2+1)
Out2=1/8 * In * (D+1)*(-1j*D1*PS1+1j)*(D2*PS2+1)
Out3=1/8 * In * (D+1)*(D1*PS1+1)*(D2*PS3+1)
Out4=1/8 * In * (D+1)*(-1j*D1*PS1+1j)*(D2*PS3+1)

Out5=1/8 * In * 1j*(-D+1)*(D1*PS1_1+1)*(D2*PS4+1)
Out6=1/8 * In * 1j*(-D+1)*(-1j*D1*PS1_1+1j)*(D2*PS4+1)
Out7=1/8 * In * 1j*(-D+1)*(D1*PS1_1+1)*(D2*PS5+1)
Out8=1/8 * In * 1j*(-D+1)*(-1j*D1*PS1_1+1j)*(D2*PS5+1)


plt.figure(figsize=(10, 5))
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out1)**2),label='o1')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out2)**2),label='o2')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out3)**2),label='o3')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out4)**2),label='o4')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out5)**2),linestyle='--',color='r',label='o5')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out6)**2),linestyle='--',color='b',label='o6')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out7)**2),linestyle='--',color='g',label='o7')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out8)**2),linestyle='--',label='o8')
plt.ylim(-10,0)
#plt.xlim(1530,1550)
plt.legend()
plt.title("Respuesta Espectral")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Transmisión (dB)")
plt.grid(True)
plt.show()

# %% [markdown]
# # Pruebas para disminuir los lobulos secundarios pero F

# %%
wvl = np.linspace(1500e-9,1599e-9,2000)

# 2. Parámetros de la Gaussiana
w0 = 1550e-9    # Centro
sigma = 100e-9   # Desviación estándar (ancho)

# 3. Cálculo de la función
# Asegúrate de que np.exp reciba el array completo
I = np.exp(-(wvl - w0)**2 / (2 * sigma**2))
In = I
plt.figure(figsize=(10, 5))
plt.plot(wvl * 1e9,In)
plt.title("Respuesta Espectral")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Potencia entrada")
plt.grid(True)
plt.show()

# %%
n_eff = n_eff0+(n_eff0-n_g)*(wvl-wvl0)/wvl0
#n_eff=n_eff0
beta=2*np.pi*n_eff/wvl

# Señal de entrada In



D=np.exp(-1j*beta*L)
D1=np.exp(-1j*beta*L/2)
D2=np.exp(-1j*beta*L/4)

PS1=np.exp(1j*0)
PS1_1=np.exp(1j*(np.pi/2))

PS2=np.exp(1j*np.pi*(1/4+1/2-1/8))
#PS2=np.exp(1j*np.pi)
PS3=np.exp(1j*np.pi*(3/4-1))

PS4=np.exp(1j*np.pi*(-1/2))
PS5=np.exp(1j*np.pi*(1/2))



Out1=1/8 * In * (D+1)*(D1*PS1+1)*(D2*PS2+1)
Out2=1/8 * In * (D+1)*(-1j*D1*PS1+1j)*(D2*PS2+1)
Out3=1/8 * In * (D+1)*(D1*PS1+1)*(D2*PS3+1)
Out4=1/8 * In * (D+1)*(-1j*D1*PS1+1j)*(D2*PS3+1)

Out5=1/8 * In * 1j*(-D+1)*(D1*PS1_1+1)*(D2*PS4+1)
Out6=1/8 * In * 1j*(-D+1)*(-1j*D1*PS1_1+1j)*(D2*PS4+1)
Out7=1/8 * In * 1j*(-D+1)*(D1*PS1_1+1)*(D2*PS5+1)
Out8=1/8 * In * 1j*(-D+1)*(-1j*D1*PS1_1+1j)*(D2*PS5+1)


plt.figure(figsize=(10, 5))
#plt.plot(wvl * 1e9, 10 * np.log10(np.abs((In * (D+1)))**2))
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out1)**2),label='o1')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out2)**2),label='o2')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out3)**2),label='o3')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out4)**2),label='o4')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out5)**2),linestyle='--',color='r',label='o5')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out6)**2),linestyle='--',color='b',label='o6')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out7)**2),linestyle='--',color='g',label='o7')
plt.plot(wvl * 1e9, 10 * np.log10(np.abs(Out8)**2),linestyle='--',label='o8')
plt.ylim(-10,0)
#plt.xlim(1530,1550)
plt.legend()
plt.title("Respuesta Espectral")
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Transmisión (dB)")
plt.grid(True)
plt.show()
